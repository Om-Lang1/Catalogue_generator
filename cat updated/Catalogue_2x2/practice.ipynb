# %%
x = 121
original = x
rev = 0
while x > 0:
        rev = rev * 10 + x % 10
        x //= 10
        
return original == rev
# Out:
#   Cell In[3], line 8
#     return original == rev
#     ^
# SyntaxError: 'return' outside function
